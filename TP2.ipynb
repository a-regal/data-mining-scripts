# %%
import pandas as pd
import matplotlib.pyplot as plt
import pylab

# %%
data = "CDO8702897422043.txt"

# %%
frame = pd.read_csv(data,sep=',',decimal='.',engine='python')

# %%
frame.columns = map(str.strip, frame.columns)
frame.columns = map(str.lower, frame.columns)

# %%
frame.drop(frame.columns[[4]], axis=1, inplace=True)

# %%
frame.keys()
# Out:
# Index([u'stn---', u'wban', u'yearmoda', u'temp', u'dewp', u'.1', u'slp', u'.2',
#        u'stp', u'.3', u'visib', u'.4', u'wdsp', u'.5', u'mxspd', u'gust',
#        u'max', u'min', u'prcp', u'sndp', u'frshtt', u'unnamed: 22'],
#       dtype='object')

# %%
frame.drop(frame.columns[[0,1,-1]],axis=1,inplace=True)

# %%
frame['yearmoda'] = frame['yearmoda'].apply(str)

# %%
# %matplotlib inline

# %%
for index, row in frame.iterrows():
    frame.ix[index, 'celsius'] = (row['temp']-32)/1.8
# Out:
# /home/andres/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
x = frame["date"]
y = frame["celsius"]
plt.plot(x, y)
pylab.show()

# %%
from datetime import date

# %%
for index, row in frame.iterrows():
    frame.ix[index,'date'] = date(int(row['yearmoda'][0:4]),int(row['yearmoda'][4:6]),int(row['yearmoda'][6:]))

# %%
frame['date']
# Out:
# 0      2017-01-02
# 1      2017-01-03
# 2      2017-01-04
# 3      2017-01-05
# 4      2017-01-06
# 5      2017-01-07
# 6      2017-01-08
# 7      2017-01-09
# 8      2017-01-10
# 9      2017-01-11
# 10     2017-01-12
# 11     2017-01-13
# 12     2017-01-14
# 13     2017-01-15
# 14     2017-01-16
# 15     2017-01-17
# 16     2017-01-18
# 17     2017-01-19
# 18     2017-01-20
# 19     2017-01-21
# 20     2017-01-22
# 21     2017-01-23
# 22     2017-01-24
# 23     2017-01-25
# 24     2017-01-26
# 25     2017-01-27
# 26     2017-01-28
# 27     2017-01-29
# 28     2017-01-30
# 29     2017-01-31
#           ...
# 210    2017-07-31
# 211    2017-08-01
# 212    2017-08-02
# 213    2017-08-03
# 214    2017-08-04
# 215    2017-08-05
# 216    2017-08-06
# 217    2017-08-07
# 218    2017-08-08
# 219    2017-08-09
# 220    2017-08-10
# 221    2017-08-11
# 222    2017-08-12
# 223    2017-08-13
# 224    2017-08-14
# 225    2017-08-15
# 226    2017-08-16
# 227    2017-08-17
# 228    2017-08-18
# 229    2017-08-19
# 230    2017-08-20
# 231    2017-08-21
# 232    2017-08-22
# 233    2017-08-23
# 234    2017-08-24
# 235    2017-08-25
# 236    2017-08-26
# 237    2017-08-27
# 238    2017-08-28
# 239    2017-08-29
# Name: date, Length: 240, dtype: object
